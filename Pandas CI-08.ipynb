# %%
from pandas import DataFrame, read_csv
import matplotlib.pyplot as plt
import pandas as pd 
import sys 
import matplotlib

# %%
print('Python version ' + sys.version)
print('Pandas version ' + pd.__version__)
print('Matplotlib version ' + matplotlib.__version__)
# Out:
# Python version 3.7.12 (default, Jan 15 2022, 18:48:18)
# [GCC 7.5.0]
# Pandas version 1.3.5
# Matplotlib version 3.2.2

# %%
names = ['Abhishek','Amit','Siddharth','Patel','ram']
births = [968, 50, 180, 578, 973]
BabyDataSet = list(zip(names,births))
BabyDataSet
# Out:
# [('Abhishek', 968),
#  ('Amit', 50),
#  ('Siddharth', 180),
#  ('Patel', 578),
#  ('ram', 973)]

# %%
df = pd.DataFrame(data = BabyDataSet, columns=['Names', 'Births'])
df
# Out:
#        Names  Births
# 0   Abhishek     968
# 1       Amit      50
# 2  Siddharth     180
# 3      Patel     578
# 4        ram     973

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
Df1=pd.read_csv("/content/drive/MyDrive/6th sem/Salary_Data.csv")
Df1.head(5)
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0

# %%
Df1.dtypes
# Out:
# YearsExperience    float64
# Salary             float64
# dtype: object

# %%
Sorted=Df1.sort_values(['Salary'], ascending=False)
Sorted.head(5)
# Out:
#     YearsExperience    Salary
# 28             10.3  122391.0
# 29             10.5  121872.0
# 26              9.5  116969.0
# 23              8.2  113812.0
# 27              9.6  112635.0

# %%
Df1.loc[10]
# Out:
# YearsExperience        3.9
# Salary             63218.0
# Name: 10, dtype: float64

# %%
Df1.groupby("Salary")
